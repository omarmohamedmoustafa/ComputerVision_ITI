# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# # Filter

# %%
def CallBack(Copy_x):
    pass
img = np.zeros((900,900,3),np.uint8)
img[450:,:]=[255,255,255]
plt.imshow(img)
#cv2.namedWindow('img')
#cv2.createTrackbar('Blur','img',0,20,CallBack)
#x=cv2.getTrackbarPos('Blur','img')
gaussian = cv2.bilateralFilter(img,300,75,75)
plt.imshow(gaussian)
